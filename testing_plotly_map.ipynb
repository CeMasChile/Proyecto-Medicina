# %%
import geopandas as gpd
cuarteles = gpd.read_file('./data/Carabineros/Cuarteles_Carabineros/CUARTELES.shp')

# %%
import plotly.express as px
token=open("token.txt").read()
px.set_mapbox_access_token(token)
carshare = cuarteles
fig = px.scatter_mapbox(lon=cuarteles['geometry'].x,lat=cuarteles['geometry'].y,color_continuous_scale=px.colors.cyclical.IceFire, hover_name=cuarteles['NOMBRE_UNI'], size_max=15, zoom=10)
fig.show()
# Out:
# <div>
#
#
#             <div id="9661e4c6-033d-48b7-97b4-5c2efcc9ee49" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9661e4c6-033d-48b7-97b4-5c2efcc9ee49")) {
#                     Plotly.newPlot(
#                         '9661e4c6-033d-48b7-97b4-5c2efcc9ee49',
# ...
